# %% [markdown]
# # ColabでPhysicsNeMoを動かす

# %% [markdown]
# GoogleDriveへのアクセス権限が必要（アクセス許可をします．）
#
# GoogleDrive内にphysicsnemo_workspaceという名前のフォルダを作成し，その中にこのmain.ipynbを置く．
#
# ランタイムのタイプをT4 GPUに変更（使いすぎると使用不可になります，なりました．）

# %% [markdown]
# ### GoogleDriveをマウントし，Drive内にPhysicsNeMoをクローン

# %%
from google.colab import drive
import os

drive.mount("/content/drive")

# %cd "/content/drive/MyDrive/physicsnemo_workspace"

# !git clone https://github.com/NVIDIA/physicsnemo.git
# !git clone https://github.com/NVIDIA/physicsnemo-sym.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/physicsnemo_workspace
# fatal: destination path 'physicsnemo' already exists and is not an empty directory.
# fatal: destination path 'physicsnemo-sym' already exists and is not an empty directory.

# %% [markdown]
# これでGoogleDriveの`マイドライブ/physicsnemo_workspace/`の下に`physicsnemo`と`physicsnemo-sym`がダウンロードされる．

# %% [markdown]
# ### PhysicsNeMoのインストール

# %% [markdown]
# #### ソースコードからインストールしようとしたがphysicsnemo-symのほうがエラーが発生してできなかった．
#
# ```
# Obtaining file:///content/drive/MyDrive/physicsnemo_workspace/physicsnemo-sym
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build editable did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build editable ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build editable did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ```

# %% [markdown]
# ```
# !sudo add-apt-repository -y ppa:deadsnakes/ppa
# !sudo apt-get -y update
# !sudo apt-get -y install python3.10
# !sudo apt-get -y install python3.10-dev
# !sudo apt-get -y install python3-pip
# !sudo apt-get -y install python3.10-distutils
#
# !python3.10 -m pip install --upgrade setuptools
# !python3.10 -m pip install --upgrade pip
# !python3.10 -m pip install --upgrade distlib
#
# %cd "/content/drive/MyDrive/physicsnemo_workspace"
# %cd "physicsnemo"
# !python3.10 -m pip install -e .
# %cd "../physicsnemo-sym"
# !python3.10 -m pip install Cython
# !python3.10 -m pip install -e .
# ```

# %% [markdown]
# ### physicsnemoのインストール（PyPI）
#
# physicsnemo-symのインストールでセッションの再起動が求められる（かも）

# %%
# %cd "/content/drive/MyDrive/physicsnemo_workspace"
# !pip install nvidia-physicsnemo
# !pip install Cython
# !pip install nvidia-physicsnemo-sym --no-build-isolation
# Out:
# /content/drive/MyDrive/physicsnemo_workspace
# ...

# %% [markdown]
# ### FNOを使用したDarcyFlowの学習のexampleの実行（physicsnemo）

# %%
# %cd "/content/drive/MyDrive/physicsnemo_workspace/physicsnemo/examples/cfd/darcy_fno"
# !pip install -r requirements.txt
# !python train_fno_darcy.py
# Out:
# /content/drive/MyDrive/physicsnemo_workspace/physicsnemo/examples/cfd/darcy_fno
# ...
# Warp CUDA error: Could not open libcuda.so.
# Warp CUDA error: Function cuDriverGetVersion_f: a suitable driver entry point was not found
# Warp CUDA error 36 (in function cuda_driver_version, /builds/omniverse/warp/warp/native/warp.cu:1719)
# Warp 1.7.2 initialized:
#    CUDA Toolkit 12.8, Driver 0.0 (insufficient CUDA driver version!)
#    Devices:
#      "cpu"      : "x86_64"
#    Kernel cache:
#      /root/.cache/warp/1.7.2
# Warp UserWarning:
#    Insufficient CUDA driver version.
#    The minimum required CUDA driver version is 12.0, but the installed CUDA driver version is 0.0.
#    Visit https://github.com/NVIDIA/warp/blob/main/README.md#installing for guidance.
# /usr/local/lib/python3.11/dist-packages/physicsnemo/distributed/manager.py:415: UserWarning: Could not initialize using ENV, SLURM or OPENMPI methods. Assuming this is a single process job
#   warn(
# ...

# %% [markdown]
# ### physicsnemo-sym

# %% [markdown]
# GPUの使用制限によりテストできず

# %%
# %cd "/content/drive/MyDrive/physicsnemo_workspace/physicsnemo-sym/examples/ldc/"
# !python ldc_2d.py
# Out:
# /content/drive/MyDrive/physicsnemo_workspace/physicsnemo-sym/examples/ldc
# 2025-06-11 04:14:14.713664: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749615254.737416    2952 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749615254.744588    2952 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-11 04:14:14.768029: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
